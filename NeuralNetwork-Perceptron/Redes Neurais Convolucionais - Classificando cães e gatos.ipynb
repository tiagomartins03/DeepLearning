# %% [markdown]
# # Classificando cães 🐕 e gatos 🐈
#
#
#
#
#
#
# Você já imaginou criar uma rede neural para classificar imagens? As redes neurais convolucionais (CNNs) são amplamente utilizadas em uma variedade de aplicações de visão computacional e processamento de imagens devido à sua capacidade de aprender representações hierárquicas de dados.
#
# Na aula de hoje vamos criar uma rede neural para classificar cães e gatos. Sabemos que para os olhos humanos é fácil a identificação dos animais por meio de algumas diferenças entre ambos, tal como gatos possuem os olhos mais puxadinhos, orelhinhas mais pontudas e entre outras características. Mas também sabemos que temos cães que podem ter características semelhantes ao gato, tal como a orelhinha pontuda, cauda longa, e entre outras características. Será que a rede neural consegue distinguir os animais? Vamos codar e descobrir juntos!!
# ![caoegatinho.PNG](data:image/png;base64,...)
# # Sobre a base de dados
# Essa base de dados está disponível no Kaggle, lá é possível encontrar diversas bases para trabalhar com dados de visão computacional! Para nossa aula de hoje, selecionei essa base de gatinhos e cachorrinhos fofos!
#
# Link: https://www.kaggle.com/datasets/moazeldsokyx/dogs-vs-cats

# %% [markdown]
# ## Importando as bibliotecas que vamos utilizar na aula de hoje:

# %%
# Bibliotecas essenciais
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os
import cv2

# Para Deep Learning
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense, Dropout, Conv2D, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam

# Para validação do modelo
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
caminho_da_pasta = "C:\\Users\\User\\Desktop\\Neural Network\\Aula2_RedesConvolucionais\\images"
pasta_imagens = Path(caminho_da_pasta)

# %% [markdown]
# Depois de importar as bibliotecas necessárias para realizar nosso projeto, vamos utilizar o glob para listar as imagens que possuem o padrão ".jpg" (que no caso são as imagens de cachorrinhos e gatinhos que estão aqui na pasta do drive).

# %%
# Listando todas as imagens do diretório
filepaths = list(pasta_imagens.glob(r'**/*.jpg'))
filepaths
# Out:
# [WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.0.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.1.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.100.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.101.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.102.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.103.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.104.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.105.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.106.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.109.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.111.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.112.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.113.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.114.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.115.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.116.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.117.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.118.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.119.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.120.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.121.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.122.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12240.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12241.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12243.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12244.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12246.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12247.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12248.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12249.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12250.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12251.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12252.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12253.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12254.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12258.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12259.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12260.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12261.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12263.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12264.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12265.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12266.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12267.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12271.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12272.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12273.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12274.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12275.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12277.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12278.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12280.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12281.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12282.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12283.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12284.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12285.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12286.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12287.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12288.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12289.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12291.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12292.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12293.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12294.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12295.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12296.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12298.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12299.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.123.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12300.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12301.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12303.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12304.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12305.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12307.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12308.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12309.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12310.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12312.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12314.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12315.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12316.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12317.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12318.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12319.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12320.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12321.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12322.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12323.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12325.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12327.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12328.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12329.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12330.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12332.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12334.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12335.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12336.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12338.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12340.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12341.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12342.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12343.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12346.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12347.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12348.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12349.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12350.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12352.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12353.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12354.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12355.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12357.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12358.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12359.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12360.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12361.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12362.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12364.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12365.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12366.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12367.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12369.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12370.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12371.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12372.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12373.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12374.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12375.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12376.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12377.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12378.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12380.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12381.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12382.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12383.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12384.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12387.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12391.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12392.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12393.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12394.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12395.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12396.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12397.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12399.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.124.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12403.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12404.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12406.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12407.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12408.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12409.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12410.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12411.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12412.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12413.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12414.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12415.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12416.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12417.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12420.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12421.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12422.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12424.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12425.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12426.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12427.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12428.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12431.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12432.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12434.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12435.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12437.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12438.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12439.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12440.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12441.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12442.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12443.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12444.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12446.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12447.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12448.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12449.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12450.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12451.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12452.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12453.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12454.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12456.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12457.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12458.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12459.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12461.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12465.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12467.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12468.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12469.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12470.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12471.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12472.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12473.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12474.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12476.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12477.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12479.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12480.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12481.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12482.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12483.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12484.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12485.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12487.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12489.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12490.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12491.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12492.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12493.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12495.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12496.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12497.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.12498.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.125.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.126.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.127.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.128.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.129.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.13.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.130.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.131.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.132.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.133.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.134.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.135.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.136.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.138.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.139.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.14.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.140.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.141.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.142.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.144.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.145.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.146.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.147.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.149.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.15.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.150.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.151.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.152.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.153.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.154.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.155.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.156.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.157.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.158.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.159.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.16.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.160.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.161.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.163.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.164.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.165.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.166.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.167.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.168.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.17.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.170.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.171.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.172.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.173.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.176.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.177.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.178.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.179.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.18.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.180.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.181.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.182.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.183.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.184.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.185.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.187.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.188.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.189.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.19.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.190.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.191.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.192.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.193.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.194.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.196.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.197.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.198.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.199.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.20.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.200.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.201.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.205.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.206.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.208.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.209.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.21.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.210.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.211.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.212.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.213.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.214.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.215.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.216.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.217.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.218.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.219.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.22.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.220.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.221.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.222.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.223.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.225.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.226.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.227.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.228.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.229.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.23.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.230.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.231.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.232.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.234.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.237.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.238.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.239.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.24.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.240.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.241.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.242.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.243.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.244.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.245.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.246.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.247.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.248.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.249.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.251.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.252.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.253.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.254.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.256.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.257.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.259.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.26.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.260.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.261.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.262.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.264.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.265.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.266.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.267.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.268.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.269.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.270.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.272.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.273.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.274.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.276.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.277.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.278.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.28.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.280.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.281.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.282.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.283.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.284.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.285.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.286.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.287.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.288.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.289.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.29.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.291.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.292.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.293.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.295.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.296.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.299.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.3.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.30.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.300.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.302.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.303.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.304.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.305.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.307.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.309.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.31.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.310.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.311.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.312.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.313.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.314.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.316.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.318.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.319.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.32.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.320.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.322.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.323.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.324.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.325.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.326.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.327.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.329.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.33.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.330.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.331.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.332.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.333.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.335.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.336.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.337.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.338.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.339.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.34.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.341.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.342.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.343.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.345.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.346.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.347.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.349.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.350.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.353.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.354.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.355.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.356.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.357.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.358.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.359.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.36.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.360.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.361.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.362.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.363.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.364.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.365.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.367.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.368.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.369.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.371.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.374.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.375.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.376.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.377.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.378.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.379.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.38.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.380.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.381.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.382.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/cat/cat.383.jpg'),
# ...
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12408.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12409.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12410.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12411.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12412.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12414.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12415.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12416.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12417.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12418.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12419.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12420.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12421.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12422.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12424.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12425.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12427.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12428.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12429.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12430.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12431.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12432.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12433.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12434.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12435.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12436.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12437.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12438.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12439.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12440.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12441.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12442.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12444.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12447.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12448.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12450.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12451.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12452.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12453.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12454.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12455.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12457.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12458.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12459.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12460.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12461.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12462.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12464.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12467.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12468.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12469.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12470.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12471.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12472.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12473.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12474.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12475.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12476.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12477.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12478.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12480.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12481.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12482.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12483.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12484.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12485.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12486.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12488.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12489.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12490.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12492.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12493.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12494.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12495.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12497.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.12499.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.125.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.126.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.128.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.13.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.130.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.131.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.132.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.133.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.134.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.135.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.136.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.137.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.138.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.140.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.141.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.142.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.143.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.144.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.145.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.147.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.148.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.149.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.150.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.151.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.153.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.154.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.155.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.156.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.157.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.158.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.159.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.16.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.160.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.161.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.162.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.163.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.164.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.165.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.166.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.167.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.168.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.169.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.17.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.170.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.171.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.172.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.173.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.174.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.175.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.177.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.178.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.179.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.18.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.180.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.182.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.183.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.184.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.185.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.186.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.187.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.188.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.19.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.190.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.191.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.192.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.193.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.194.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.195.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.196.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.197.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.198.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.199.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.2.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.200.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.201.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.202.jpg'),
#  WindowsPath('C:/Users/User/Desktop/Neural Network/Aula2_RedesConvolucionais/images/dog/dog.203.jpg'),
#  ...]

# %% [markdown]
# ## Tratando os dados
#
# Como próximo passo, vamos armazenar as **targets** do nosso modelo e as **imagens** em uma **lista**. Para todas as imagens localizadas em filepaths, vamos percorrer com um **loop cada uma das imagens e realizar algumas tratativas** como por exemplo redimensionar a imagem e normalizar o intervalo de pixels para ficar entre 0 e 1 e armazena-las nas listas.
#
# Aqui é importante relembrar que redes neurais funcionam melhor quando estão com os dados normalizados ou padronizados.

# %%
# Inicializando rótulos e listas de imagens para armazenar os dados
labels = [] #armazenando as variáveis target
images = [] #armazenando imagens

# Definindo o tamanho da dimensão da imagem
image_size = 64

# Um loop for para definir as variáveis x e y para os modelos
for filepath in filepaths:
    # Divide o nome do caminho para extrair o cabeçalho do caminho com split
    head = os.path.split(filepath)
    # Divide o cabeçalho do caminho anterior para extrair o nome do animal
    animal = os.path.split(head[0])
    # Armazena o nome do animal na lista de labels
    labels.append(animal[1])
    # Obtem a imagem do caminho com cv2
    img = cv2.imread(str(filepath))
    # Redimensiona a imagem e normalize o intervalo de pixels para ficar entre 0 e 1 (padronização)
    # Utilizando float32 para criar uma precisão limitada (menor demanda de memória em comparação com tipos de ponto flutuante de maior precisão: float64)
    img = cv2.resize(img, (image_size, image_size)).astype('float32') / 255.0
    # Adiciona a imagem na lista de imagens
    images.append(img)

# Converte a imagem em lista de array
images = np.array(images)
# Converte as labels para lista de array
labels = np.array(labels)

# %% [markdown]
# Muito bem! Agora temos as imagens armazenadas em um formato de um grande array na variável "images" e os rótulos em "labels".

# %%
images.shape
# Out:
# (1400, 64, 64, 3)

# %%
images
# Out:
# array([[[[0.3529412 , 0.654902  , 0.80784315],
#          [0.3764706 , 0.6784314 , 0.83137256],
#          [0.39607844, 0.7019608 , 0.87058824],
#          ...,
#          [0.53333336, 0.8392157 , 0.9764706 ],
#          [0.5019608 , 0.81960785, 0.9647059 ],
#          [0.47843137, 0.79607844, 0.9529412 ]],
#
#         [[0.3529412 , 0.654902  , 0.80784315],
#          [0.3764706 , 0.6784314 , 0.83137256],
#          [0.39607844, 0.7019608 , 0.87058824],
#          ...,
#          [0.5568628 , 0.8509804 , 0.972549  ],
#          [0.5254902 , 0.83137256, 0.96862745],
#          [0.49411765, 0.80784315, 0.95686275]],
#
#         [[0.3529412 , 0.654902  , 0.80784315],
#          [0.3764706 , 0.6784314 , 0.83137256],
#          [0.39607844, 0.7019608 , 0.87058824],
#          ...,
#          [0.5686275 , 0.85490197, 0.9647059 ],
#          [0.5529412 , 0.84705883, 0.972549  ],
#          [0.5137255 , 0.81960785, 0.96862745]],
#
#         ...,
#
#         [[0.22352941, 0.5019608 , 0.63529414],
#          [0.23921569, 0.5176471 , 0.6509804 ],
#          [0.24705882, 0.5254902 , 0.67058825],
#          ...,
#          [0.        , 0.01568628, 0.01176471],
#          [0.        , 0.01568628, 0.01176471],
#          [0.        , 0.01176471, 0.00784314]],
#
#         [[0.21176471, 0.49019608, 0.627451  ],
#          [0.22352941, 0.5019608 , 0.63529414],
#          [0.23137255, 0.50980395, 0.654902  ],
#          ...,
#          [0.        , 0.01568628, 0.01176471],
#          [0.        , 0.01568628, 0.01176471],
#          [0.        , 0.01176471, 0.00784314]],
#
#         [[0.21960784, 0.48235294, 0.6039216 ],
#          [0.23529412, 0.5019608 , 0.61960787],
#          [0.22745098, 0.50980395, 0.6431373 ],
#          ...,
#          [0.        , 0.00784314, 0.00784314],
#          [0.        , 0.00784314, 0.00784314],
#          [0.        , 0.00784314, 0.00784314]]],
#
#
#        [[[0.16862746, 0.17254902, 0.15686275],
#          [0.1882353 , 0.16470589, 0.15294118],
#          [0.15294118, 0.14509805, 0.12941177],
#          ...,
#          [0.40392157, 0.3137255 , 0.2784314 ],
#          [0.49411765, 0.5019608 , 0.49019608],
#          [0.64705884, 0.77254903, 0.78431374]],
#
#         [[0.15294118, 0.16078432, 0.14117648],
#          [0.1764706 , 0.14901961, 0.14117648],
#          [0.18431373, 0.1764706 , 0.16078432],
#          ...,
#          [0.4509804 , 0.34901962, 0.3137255 ],
#          [0.49803922, 0.4862745 , 0.47843137],
#          [0.64705884, 0.7490196 , 0.78039217]],
#
#         [[0.15294118, 0.15686275, 0.14117648],
#          [0.16862746, 0.14509805, 0.13333334],
#          [0.2509804 , 0.23921569, 0.22352941],
#          ...,
#          [0.47843137, 0.39607844, 0.34901962],
#          [0.4862745 , 0.49411765, 0.48235294],
#          [0.6666667 , 0.78039217, 0.827451  ]],
#
#         ...,
#
#         [[0.09019608, 0.09019608, 0.09019608],
#          [0.08235294, 0.08235294, 0.08235294],
#          [0.09411765, 0.09411765, 0.09411765],
#          ...,
#          [0.2509804 , 0.25490198, 0.30980393],
#          [0.29411766, 0.29803923, 0.35686275],
#          [0.15294118, 0.18039216, 0.23921569]],
#
#         [[0.07843138, 0.07450981, 0.08235294],
#          [0.07450981, 0.07058824, 0.07843138],
#          [0.08627451, 0.08235294, 0.09019608],
#          ...,
#          [0.07058824, 0.07843138, 0.14901961],
#          [0.19607843, 0.20784314, 0.27450982],
#          [0.1764706 , 0.1882353 , 0.24313726]],
#
#         [[0.10196079, 0.09411765, 0.10588235],
#          [0.09019608, 0.08627451, 0.09411765],
#          [0.09019608, 0.08627451, 0.09803922],
#          ...,
#          [0.24705882, 0.2627451 , 0.33333334],
#          [0.23137255, 0.2509804 , 0.3137255 ],
#          [0.07450981, 0.10196079, 0.15294118]]],
#
#
#        [[[0.8509804 , 0.87058824, 0.8627451 ],
#          [0.85490197, 0.8745098 , 0.87058824],
#          [0.8980392 , 0.9098039 , 0.90588236],
#          ...,
#          [0.99607843, 0.98039216, 0.9764706 ],
#          [0.95686275, 0.9372549 , 0.9372549 ],
#          [0.95686275, 0.9372549 , 0.93333334]],
#
#         [[0.85490197, 0.8745098 , 0.87058824],
#          [0.8392157 , 0.85882354, 0.85490197],
#          [0.89411765, 0.9098039 , 0.90588236],
#          ...,
#          [0.9764706 , 0.95686275, 0.9529412 ],
#          [1.        , 0.9843137 , 0.98039216],
#          [0.9764706 , 0.95686275, 0.9490196 ]],
#
#         [[0.8627451 , 0.88235295, 0.8784314 ],
#          [0.87058824, 0.8901961 , 0.8862745 ],
#          [0.87058824, 0.8901961 , 0.8862745 ],
#          ...,
#          [0.99607843, 0.98039216, 0.9764706 ],
#          [0.99215686, 0.972549  , 0.96862745],
#          [0.96862745, 0.9529412 , 0.9490196 ]],
#
#         ...,
#
#         [[0.8235294 , 0.80784315, 0.7921569 ],
#          [0.8       , 0.7607843 , 0.78431374],
#          [0.6862745 , 0.6313726 , 0.68235296],
#          ...,
#          [0.87058824, 0.8745098 , 0.85882354],
#          [0.8156863 , 0.83137256, 0.8352941 ],
#          [0.8156863 , 0.83137256, 0.84705883]],
#
#         [[0.7921569 , 0.7882353 , 0.7490196 ],
#          [0.7647059 , 0.7764706 , 0.76862746],
#          [0.8156863 , 0.76862746, 0.83137256],
#          ...,
#          [0.87058824, 0.8745098 , 0.85882354],
#          [0.81960785, 0.8352941 , 0.8392157 ],
#          [0.81960785, 0.8352941 , 0.8509804 ]],
#
#         [[0.84705883, 0.8235294 , 0.84313726],
#          [0.7921569 , 0.79607844, 0.8117647 ],
#          [0.7058824 , 0.6431373 , 0.7254902 ],
#          ...,
#          [0.8627451 , 0.8666667 , 0.8509804 ],
#          [0.8235294 , 0.8392157 , 0.84313726],
#          [0.8156863 , 0.83137256, 0.84705883]]],
#
#
#        ...,
#
#
#        [[[0.40392157, 0.4       , 0.42745098],
#          [0.37254903, 0.3529412 , 0.35686275],
#          [0.48235294, 0.45882353, 0.4627451 ],
#          ...,
#          [0.9372549 , 0.95686275, 0.98039216],
#          [0.8980392 , 0.93333334, 0.9843137 ],
#          [0.8666667 , 0.8980392 , 0.9607843 ]],
#
#         [[0.31764707, 0.33333334, 0.37254903],
#          [0.40392157, 0.4       , 0.43137255],
#          [0.52156866, 0.49803922, 0.5019608 ],
#          ...,
#          [0.8745098 , 0.9137255 , 0.9490196 ],
#          [0.90588236, 0.92941177, 0.95686275],
#          [0.31764707, 0.29803923, 0.29803923]],
#
#         [[0.36862746, 0.3529412 , 0.37254903],
#          [0.4745098 , 0.4509804 , 0.44705883],
#          [0.44313726, 0.41960785, 0.42352942],
#          ...,
#          [0.48235294, 0.48235294, 0.5372549 ],
#          [0.3019608 , 0.30588236, 0.3019608 ],
#          [0.17254902, 0.17254902, 0.2       ]],
#
#         ...,
#
#         [[0.4509804 , 0.41568628, 0.42745098],
#          [0.4627451 , 0.42745098, 0.4392157 ],
#          [0.4627451 , 0.42745098, 0.4392157 ],
#          ...,
#          [0.68235296, 0.7137255 , 0.7411765 ],
#          [0.7490196 , 0.76862746, 0.8156863 ],
#          [0.7294118 , 0.7529412 , 0.79607844]],
#
#         [[0.47843137, 0.43137255, 0.43137255],
#          [0.5137255 , 0.4862745 , 0.5176471 ],
#          [0.40392157, 0.36862746, 0.39607844],
#          ...,
#          [0.7176471 , 0.7254902 , 0.75686276],
#          [0.68235296, 0.7058824 , 0.7490196 ],
#          [0.76862746, 0.7921569 , 0.8352941 ]],
#
#         [[0.4       , 0.3647059 , 0.3764706 ],
#          [0.4392157 , 0.40392157, 0.41568628],
#          [0.43529412, 0.38431373, 0.39215687],
#          ...,
#          [0.6313726 , 0.6431373 , 0.6627451 ],
#          [0.68235296, 0.69411767, 0.7137255 ],
#          [0.6039216 , 0.6039216 , 0.65882355]]],
#
#
#        [[[0.5372549 , 0.67058825, 0.8509804 ],
#          [0.36078432, 0.49803922, 0.6901961 ],
#          [0.38039216, 0.5254902 , 0.6901961 ],
#          ...,
#          [0.02352941, 0.19607843, 0.38039216],
#          [0.03529412, 0.16470589, 0.34117648],
#          [0.19215687, 0.26666668, 0.42745098]],
#
#         [[0.39607844, 0.50980395, 0.68235296],
#          [0.50980395, 0.65882355, 0.8117647 ],
#          [0.39607844, 0.59607846, 0.7490196 ],
#          ...,
#          [0.16862746, 0.34901962, 0.5294118 ],
#          [0.13725491, 0.2627451 , 0.4392157 ],
#          [0.1764706 , 0.23921569, 0.39215687]],
#
#         [[0.34117648, 0.47058824, 0.6666667 ],
#          [0.3647059 , 0.5568628 , 0.72156864],
#          [0.54509807, 0.75686276, 0.9019608 ],
#          ...,
#          [0.43529412, 0.60784316, 0.78039217],
#          [0.49019608, 0.6313726 , 0.8       ],
#          [0.2       , 0.28627452, 0.43137255]],
#
#         ...,
#
#         [[0.36078432, 0.5137255 , 0.6862745 ],
#          [0.5921569 , 0.79607844, 0.9137255 ],
#          [0.4745098 , 0.7019608 , 0.827451  ],
#          ...,
#          [0.25490198, 0.49019608, 0.68235296],
#          [0.10196079, 0.2784314 , 0.45882353],
#          [0.1254902 , 0.20392157, 0.3764706 ]],
#
#         [[0.43137255, 0.5921569 , 0.7882353 ],
#          [0.41960785, 0.56078434, 0.73333335],
#          [0.36078432, 0.5176471 , 0.68235296],
#          ...,
#          [0.08627451, 0.25882354, 0.47058824],
#          [0.14117648, 0.23529412, 0.41960785],
#          [0.34117648, 0.45490196, 0.64705884]],
#
#         [[0.5019608 , 0.59607846, 0.7921569 ],
#          [0.45490196, 0.5686275 , 0.7921569 ],
#          [0.5176471 , 0.6392157 , 0.827451  ],
#          ...,
#          [0.5137255 , 0.74509805, 0.8980392 ],
#          [0.21176471, 0.38039216, 0.58431375],
#          [0.24313726, 0.32941177, 0.49803922]]],
#
#
#        [[[0.69803923, 0.69803923, 0.69803923],
#          [0.69803923, 0.69803923, 0.69803923],
#          [0.69803923, 0.69803923, 0.69803923],
#          ...,
#          [0.4745098 , 0.5647059 , 0.6901961 ],
#          [0.5019608 , 0.5921569 , 0.7176471 ],
#          [0.3764706 , 0.5372549 , 0.6509804 ]],
#
#         [[0.69803923, 0.69803923, 0.69803923],
#          [0.69803923, 0.69803923, 0.69803923],
#          [0.69803923, 0.69803923, 0.69803923],
#          ...,
#          [0.40392157, 0.49411765, 0.62352943],
#          [0.43529412, 0.5254902 , 0.6509804 ],
#          [0.45882353, 0.54901963, 0.6745098 ]],
#
#         [[0.69803923, 0.69803923, 0.69803923],
#          [0.69803923, 0.69803923, 0.69803923],
#          [0.69803923, 0.69803923, 0.69803923],
#          ...,
#          [0.4       , 0.49019608, 0.6117647 ],
#          [0.4627451 , 0.5529412 , 0.6784314 ],
#          [0.39215687, 0.49411765, 0.61960787]],
#
#         ...,
#
#         [[0.16078432, 0.47843137, 0.7411765 ],
#          [0.15686275, 0.4745098 , 0.7372549 ],
#          [0.20392157, 0.52156866, 0.7882353 ],
#          ...,
#          [0.07058824, 0.4       , 0.627451  ],
#          [0.08235294, 0.4117647 , 0.63529414],
#          [0.12941177, 0.45882353, 0.6862745 ]],
#
#         [[0.25490198, 0.58431375, 0.80784315],
#          [0.14509805, 0.47843137, 0.69803923],
#          [0.16862746, 0.49803922, 0.73333335],
#          ...,
#          [0.07450981, 0.40392157, 0.6313726 ],
#          [0.07843138, 0.40784314, 0.63529414],
#          [0.07450981, 0.40392157, 0.6313726 ]],
#
#         [[0.1882353 , 0.5176471 , 0.74509805],
#          [0.24313726, 0.57254905, 0.8       ],
#          [0.18039216, 0.50980395, 0.7372549 ],
#          ...,
#          [0.07450981, 0.40392157, 0.6313726 ],
#          [0.07450981, 0.40392157, 0.6313726 ],
#          [0.07450981, 0.40392157, 0.6313726 ]]]], dtype=float32)

# %%
labels
# Out:
# array(['cat', 'cat', 'cat', ..., 'dog', 'dog', 'dog'], dtype='<U3')

# %% [markdown]
# ## Construindo um dataframe
#
# Com as imagens e rotulos já definidos, vamos construir um dataframe com o nome do caminho e o rótulo da imagem.

# %%
# Salvando a lista de caminhos de arquivo
pd_filepaths = pd.Series(filepaths, name='Filepath').astype(str)

# %%
# Visualizando o camiho das imagens
print(pd_filepaths[:3])
# Out:
# 0    C:\Users\User\Desktop\Neural Network\Aula2_Red...
# 1    C:\Users\User\Desktop\Neural Network\Aula2_Red...
# 2    C:\Users\User\Desktop\Neural Network\Aula2_Red...
# Name: Filepath, dtype: object

# %%
# Visualizando os rótulos das imagens
print(labels[:3])
# Out:
# ['cat' 'cat' 'cat']

# %%
# Adicionando a label
pd_labels = pd.Series(labels, name='Label')

# %%
# Concatenando the filepaths and labels
df = pd.concat([pd_filepaths, pd_labels], axis=1)

# %%
df.head()
# Out:
#                                             Filepath Label
# 0  C:\Users\User\Desktop\Neural Network\Aula2_Red...   cat
# 1  C:\Users\User\Desktop\Neural Network\Aula2_Red...   cat
# 2  C:\Users\User\Desktop\Neural Network\Aula2_Red...   cat
# 3  C:\Users\User\Desktop\Neural Network\Aula2_Red...   cat
# 4  C:\Users\User\Desktop\Neural Network\Aula2_Red...   cat

# %%
df.tail()
# Out:
#                                                Filepath Label
# 1395  C:\Users\User\Desktop\Neural Network\Aula2_Red...   dog
# 1396  C:\Users\User\Desktop\Neural Network\Aula2_Red...   dog
# 1397  C:\Users\User\Desktop\Neural Network\Aula2_Red...   dog
# 1398  C:\Users\User\Desktop\Neural Network\Aula2_Red...   dog
# 1399  C:\Users\User\Desktop\Neural Network\Aula2_Red...   dog

# %% [markdown]
# Perceba que nossos dados estão em ordem das classes, isso pode ser um problema para o modelo, então vamos utilizar o sample para embaralhar o dataframe:

# %%
# Embaralhando o dataframe
df = df.sample(frac=1).reset_index(drop = True)

# %%
df.head()
# Out:
#                                             Filepath Label
# 0  C:\Users\User\Desktop\Neural Network\Aula2_Red...   cat
# 1  C:\Users\User\Desktop\Neural Network\Aula2_Red...   cat
# 2  C:\Users\User\Desktop\Neural Network\Aula2_Red...   dog
# 3  C:\Users\User\Desktop\Neural Network\Aula2_Red...   cat
# 4  C:\Users\User\Desktop\Neural Network\Aula2_Red...   cat

# %%
# Cria uma cópia do dataframe com apenas uma imagem de cada personagem
df_singles = df.copy().drop_duplicates(subset=('Label')).reset_index() # o subset está procurando por duplicatas apenas na coluna chamada 'Label' e removendo todas as duplicatas encontradas.

# %%
len(df_singles)
# Out:
# 2

# %%
# Define o número de classes
num_classes = df_singles.shape[0]

# %%
num_classes
# Out:
# 2

# %% [markdown]
# Show! agora que temos as classes mapeadas na variável num_classes, vamos visualizar duas amostras de imagens dentro do dataset:

# %%
# Configura o número de linhas e colunas para visualizar os dados no plot
ROW = 1
COLUMN = 2

# Dimensões das imagens
plt.figure(figsize=(12, 9))
#Loop para cada animal
for i in range(num_classes):
    # Defina uma variável de imagem local para i imagem no dataframe de singles
    image = df_singles.Filepath[i]
    # Define a posição da imagem a ser plotada
    plt.subplot(ROW, COLUMN, i+1)
    # Mostra a imagem
    plt.imshow(plt.imread(image))
    # Adiciona o rótulo do bichinho que corresponde à imagem
    plt.title('{}'.format(df_singles.Label[i]))
    # Desliga o eixo de plotagem
    plt.axis('off')
    # Faça com que o preenchimento ao redor das imagens seja mínimo
    plt.tight_layout()
plt.show()

# %% [markdown]
# ## Separando em treino e teste a base de dados
#
# Agora com as imagens e classes organizadas, podemos aplicar o train_test_split para separar as bases de treinamento e teste:

# %%
x_train, x_test, y_train, y_test = train_test_split(images,
                                           labels, test_size=0.2, stratify=labels, random_state=44)

# %%
# Analisando a dimensão dos dados
x_train.shape
# Out:
# (1120, 64, 64, 3)

# %%
x_test.shape
# Out:
# (280, 64, 64, 3)

# %% [markdown]
# Sabemos que as imagens são basicamente uma matriz de pixels e para colocar as imagens dentro da arquitetura das redes convolucionais, é preciso "achatar" essas matrizes multidimensionais em vetores unidimensionais. Uma das camadas da rede, a Flatten(), é uma das partes da rede que achata os dados antes de entrar nas camadas densas.

# %%
# Achatar os dados de teste e treinamento
x_train_flat = x_train.reshape(x_train.shape[0], x_train.shape[1]* x_train.shape[2]* x_train.shape[3])
x_test_flat = x_test.reshape(x_test.shape[0], x_test.shape[1] * x_test.shape[2] * x_test.shape[3])

# %%
# Visualizando a transformação
x_train_flat.shape
# Out:
# (1120, 12288)

# %% [markdown]
# Como próximo passo, vamos converter as classes de texto em binárias. Para esse procedimento, vamos utilizar o método LabelEncoder().

# %%
# Converter Strings em Numéricos
label_encoder = LabelEncoder()

y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.fit_transform(y_test)

# Converte um vetor de classe (inteiros) em uma matriz de classe categórica.
y_train_tf = keras.utils.to_categorical(y_train, num_classes)
y_test_tf = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
#  Vamos configurar agora como próximo passo o ModelCheckpoint para usar os melhores pesos para este modelo. Um dos benefícios do ModelCheckpoint é salvar uma cópia do modelo em disco em intervalos regulares (como após cada época de processamento) para que você possa retomar o treinamento a partir do ponto em que parou, minimizando perdas de tempo e recursos computacionais.

# %%
from distutils.file_util import copy_file

# Defina um objeto ModelCheckpoint para usar os melhores pesos para este modelo
checkpointer = ModelCheckpoint(filepath="weights.best.hdf5", verbose=0, save_best_only=True) # save best model

# %% [markdown]
# Como próximo passo, vamos definir a entrada da rede e armazenar na variável **input_shape** e em seguida configurar a learning rate e a queda do peso do otimizador com **weight_decay**.
#
#
# O argumento weight_decay é usado para aplicar **regularização L2** (também conhecida como regularização de peso) às camadas densas (fully connected) de uma rede neural durante o treinamento. A regularização L2 funciona adicionando um termo à função de perda durante o treinamento que penaliza os pesos maiores.

# %%
# Define a forma de entrada das imagens passadas pelo modelo
input_shape = (image_size, image_size, 3)

# Defina a taxa de aprendizado e a queda de peso para o otimizador usar
learning_rate = 0.001
weight_decay = 1e-4

# %% [markdown]
# Agora chegou o momento tão esperado, nossa rede neural convolucional! 🦾
#
# Acompanhe comigo o código a seguir e vamos comentando sobre cada passo da construção da rede:

# %%
tf.random.set_seed(44) # Defindo uma semente aleatória para utilizar sempre os mesmos dados durante nossos testes

model = Sequential() # Abrindo a sequencia do modelo

# 1 camada convolucional com 128 neurônios | filtro utilizando uma matriz 3x3 sendo movimentado por um stride de 2
# padding ativado (sem bordas de zeros) | função de ativação ReLU | regularização L2 ativada
model.add(Conv2D(128,
                 kernel_size=(3, 3),
                 strides=(2, 2),
                 padding='same',
                 activation='relu',
                 kernel_regularizer=keras.regularizers.l2(0.001),
                 input_shape=input_shape)),

# Camada de MaxPolling ativada, com uma matriz 2x2. Padding ativado
model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))

# Regularização de dropout ativada
model.add(Dropout(0.5))

# 2 camada convolucional com 92 neurônios | filtro utilizando uma matriz 3x3 sendo movimentado por um stride de 2
# padding ativado (sem bordas de zeros) | função de ativação ReLU | regularização L2 ativada
model.add(Conv2D(92,
                 kernel_size=(3, 3),
                 strides=(2, 2),
                 padding='same',
                 activation='relu',
                 kernel_regularizer=keras.regularizers.l2(0.001))),

# Camada de MaxPolling ativada, com uma matriz 2x2. Padding ativado
model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))

# Regularização de dropout ativada
model.add(Dropout(0.5))

# Camada que achata dos dados da imagem
model.add(Flatten())
# Camada Dense da rede neural convolucional + função de ativação ReLU
model.add(Dense(256, activation='relu'))
# Camada de saída da rede, utilizando a função de ativação softmax para criar a probabilidade de pertencimento das classes
model.add(Dense(y_train_tf.shape[1], activation='softmax'))

# %% [markdown]
# Agora vamos configurar uma técnica de validação do modelo para evitar que as épocas de processamento não executem o modelo sem ter melhoras significativas, o **early stopping**. Essa técnica monitora a perda no conjunto de validação e interrompe o treinamento se a perda não diminuir significativamente por um número especificado de épocas (10 no exemplo) após uma pequena melhoria (mínimo delta de 1e-5). Essa é uma **técnica útil para evitar o overfitting e economizar tempo de treinamento**. (Podemos dizer que essa técnica ajuda o modelo a não ficar "estagnado", ou seja, se encontra em estado estacionário).
#
# Além da configuração do early stopping, vamos configurar a função de custo com o **Adam**. A função de custo tem o papel de **ajustar os pesos de uma rede neural durante o treinamento**. o Adam também utiliza um termo de momentum para acelerar o processo de aprendizado. O momentum **ajuda o algoritmo a superar regiões planas ou mínimos locais rasos**, permitindo que ele "ganhe velocidade" na direção do mínimo global. O otimizador Adam requer menos configuração de hiperparâmetro da taxa de aprendizagem, então um valor padrão n = 0,001 pode ser uma boa opção!
#
# Lembrando que a **taxa de aprendizagem** (learning rate) é responsável por  controlar o tamanho dos “passos” das interações para encontrar um melhor mínimo local (menor erro). Uma taxa de aprendizagem baixa pode ser mais precisa, porém pode demorar para encontrar o mínimo local. Uma taxa de aprendizado alta pode deixar passar o melhor mínimo local.

# %%
# Monitor para interromper o modelo antecipadamente quando a melhoria da perda de validação for mínima
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-5, patience=10, verbose=1, mode='auto') #Aqui utilizando early stopping

# Compilando o modelo e aplicação a função de custo Adam (utilizando a learning rate que configuramos anteriormente)
model.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate), metrics=['accuracy'])

# Salve os dados do modelo em um arquivo h5
model.save('./cat_dog.h5')
# Resumo do modelo
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       3584
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 92)          106076
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 92)         0
#  2D)
#
#  dropout_3 (Dropout)         (None, 4, 4, 92)          0
#
#  flatten_1 (Flatten)         (None, 1472)              0
#
#  dense_2 (Dense)             (None, 256)               377088
#
#  dense_3 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 487,262
# Trainable params: 487,262
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Por fim, vamos configurar o número de épocas de processamento em conjunto com a base de validação das épocas. Nesse momento também é importante configurar o número de batchs que o modelo irá processar por épocas para atualizar os pesos. Em outras palavras, as batchs são as quantidades de dados de treinamento que são processadas de uma só vez antes que os pesos do modelo sejam atualizados com base nos gradientes calculados.

# %%
# Treinando o modelo
history = model.fit(x_train,y_train_tf, validation_split=0.25, callbacks=[monitor,checkpointer],
                    verbose=1,epochs=45, batch_size=50, shuffle=True)
# Out:
# Epoch 1/45
# 17/17 [==============================] - 2s 77ms/step - loss: 0.8215 - accuracy: 0.5214 - val_loss: 0.7849 - val_accuracy: 0.5000
# Epoch 2/45
# 17/17 [==============================] - 1s 60ms/step - loss: 0.7734 - accuracy: 0.5298 - val_loss: 0.7668 - val_accuracy: 0.5071
# Epoch 3/45
# 17/17 [==============================] - 1s 59ms/step - loss: 0.7627 - accuracy: 0.5262 - val_loss: 0.7589 - val_accuracy: 0.5036
# Epoch 4/45
# 17/17 [==============================] - 1s 59ms/step - loss: 0.7527 - accuracy: 0.5583 - val_loss: 0.7436 - val_accuracy: 0.5321
# Epoch 5/45
# 17/17 [==============================] - 1s 59ms/step - loss: 0.7274 - accuracy: 0.5738 - val_loss: 0.7276 - val_accuracy: 0.5643
# Epoch 6/45
# 17/17 [==============================] - 1s 59ms/step - loss: 0.7165 - accuracy: 0.5929 - val_loss: 0.7122 - val_accuracy: 0.6036
# Epoch 7/45
# 17/17 [==============================] - 1s 60ms/step - loss: 0.7036 - accuracy: 0.6107 - val_loss: 0.6965 - val_accuracy: 0.6071
# Epoch 8/45
# 17/17 [==============================] - 1s 61ms/step - loss: 0.6819 - accuracy: 0.6524 - val_loss: 0.6809 - val_accuracy: 0.6857
# Epoch 9/45
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6474 - accuracy: 0.6714 - val_loss: 0.6742 - val_accuracy: 0.6750
# Epoch 10/45
# 17/17 [==============================] - 1s 61ms/step - loss: 0.6445 - accuracy: 0.6786 - val_loss: 0.6585 - val_accuracy: 0.6893
# Epoch 11/45
# 17/17 [==============================] - 1s 60ms/step - loss: 0.6118 - accuracy: 0.7119 - val_loss: 0.6591 - val_accuracy: 0.6643
# Epoch 12/45
# 17/17 [==============================] - 1s 62ms/step - loss: 0.5985 - accuracy: 0.7083 - val_loss: 0.6458 - val_accuracy: 0.6929
# Epoch 13/45
# 17/17 [==============================] - 1s 57ms/step - loss: 0.5730 - accuracy: 0.7345 - val_loss: 0.6769 - val_accuracy: 0.6214
# Epoch 14/45
# 17/17 [==============================] - 1s 56ms/step - loss: 0.5583 - accuracy: 0.7571 - val_loss: 0.6460 - val_accuracy: 0.6714
# Epoch 15/45
# 17/17 [==============================] - 1s 54ms/step - loss: 0.5371 - accuracy: 0.7714 - val_loss: 0.6727 - val_accuracy: 0.6750
# Epoch 16/45
# 17/17 [==============================] - 1s 55ms/step - loss: 0.5571 - accuracy: 0.7345 - val_loss: 0.6912 - val_accuracy: 0.6464
# Epoch 17/45
# 17/17 [==============================] - 1s 62ms/step - loss: 0.5401 - accuracy: 0.7679 - val_loss: 0.6304 - val_accuracy: 0.7071
# Epoch 18/45
# 17/17 [==============================] - 1s 67ms/step - loss: 0.5002 - accuracy: 0.7917 - val_loss: 0.6195 - val_accuracy: 0.7179
# Epoch 19/45
# 17/17 [==============================] - 1s 57ms/step - loss: 0.4837 - accuracy: 0.7988 - val_loss: 0.6515 - val_accuracy: 0.7036
# Epoch 20/45
# 17/17 [==============================] - 1s 54ms/step - loss: 0.4816 - accuracy: 0.8048 - val_loss: 0.6351 - val_accuracy: 0.7250
# Epoch 21/45
# 17/17 [==============================] - 1s 60ms/step - loss: 0.4928 - accuracy: 0.7893 - val_loss: 0.6495 - val_accuracy: 0.6964
# Epoch 22/45
# 17/17 [==============================] - 1s 69ms/step - loss: 0.4596 - accuracy: 0.7988 - val_loss: 0.6521 - val_accuracy: 0.7107
# Epoch 23/45
# 17/17 [==============================] - 1s 57ms/step - loss: 0.4671 - accuracy: 0.8143 - val_loss: 0.6677 - val_accuracy: 0.6786
# Epoch 24/45
# 17/17 [==============================] - 1s 53ms/step - loss: 0.4507 - accuracy: 0.8083 - val_loss: 0.6719 - val_accuracy: 0.7036
# Epoch 25/45
# 17/17 [==============================] - 1s 55ms/step - loss: 0.4191 - accuracy: 0.8405 - val_loss: 0.6837 - val_accuracy: 0.6893
# Epoch 26/45
# 17/17 [==============================] - 1s 67ms/step - loss: 0.4129 - accuracy: 0.8452 - val_loss: 0.6526 - val_accuracy: 0.7250
# Epoch 27/45
# 17/17 [==============================] - 1s 68ms/step - loss: 0.4253 - accuracy: 0.8357 - val_loss: 0.6900 - val_accuracy: 0.6929
# Epoch 28/45
# 17/17 [==============================] - 1s 55ms/step - loss: 0.4005 - accuracy: 0.8429 - val_loss: 0.6858 - val_accuracy: 0.7143
# Epoch 28: early stopping

# %% [markdown]
# # Validação do modelo
#
# Existem duas métricas importantes que devemos analisar após executar a rede neural, o valor de erro observado e o valor de acurácia por épocas de processamento. Uma boa prática é analisarmos com gráficos de linhas para identificarmos as tendências da performance da rede.

# %%
# Validação o erro por épocas
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid(True)
plt.show()

# %%
# Validação da acurácia por épocas
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# Show! Agora vamos armazenar as predições da base de teste na variável de predição **cnn_pred_cat_dog**:

# %%
# Armazena as predicações do modelo dos dados de teste em uma variável
cnn_pred_cat_dog = model.predict(x_test)
# Out:
# 9/9 [==============================] - 0s 10ms/step

# %% [markdown]
# Em seguida, vamos utilizar o argmax do numpy para encontrar a classe com a maior probabilidade prevista para cada amostra. (Lembrando que utilizamos a softmax)

# %%
# Define o índice do valor máximo do modelo de previsão para uma variável
# O valor máximo indica o caractere de previsão do modelo que a imagem representa
cnn_pred_cat_dog = np.argmax(cnn_pred_cat_dog,axis=1)

# Define uma variável para armazenar o rótulo que representa o resultado verdadeiro
y_true = np.argmax(y_test_tf,axis=1)

# %% [markdown]
# Agora vamos organizar os nomes dos animais (gatinhos e cachorrinhos) em uma variável, a fim de criar uma lista única de nomes de animais, ordenados alfabeticamente. Vamos também remover duplicatas e ordenar os nomes em ordem alfabética, resultando em uma lista única, limpa e ordenada de nomes de animais.

# %%
# Cria um array de nomes de caracteres igual ao array de labels
animal_names = labels
# Reduza os nomes dos animais para apenas valores dict únicos
animal_names = list(dict.fromkeys(animal_names))
# Ordena os caracteres em ordem alfabética, qual é a ordem em que os dados são alimentados
animal_names = sorted(animal_names)

# %% [markdown]
# Importante analisar o escopo das classes, então vamos utilizar o classification_report e analisar os resultados por escopo das variáveis targets.

# %%
# Criando a matriz de confusão
cnn_cm_cat_dog = metrics.confusion_matrix(y_true, cnn_pred_cat_dog)
# Definindo a acurácia
cnn_accuracy_cat_dog = metrics.accuracy_score(y_true, cnn_pred_cat_dog)

# Print do classification report
print(metrics.classification_report(y_true, cnn_pred_cat_dog, target_names=animal_names))
# Print da acurácia
print("Accuracy score: {}".format(cnn_accuracy_cat_dog))
# Out:
#               precision    recall  f1-score   support
#
#          cat       0.63      0.78      0.70       140
#          dog       0.71      0.54      0.62       140
#
#     accuracy                           0.66       280
#    macro avg       0.67      0.66      0.66       280
# weighted avg       0.67      0.66      0.66       280
#
# Accuracy score: 0.6607142857142857

# %% [markdown]
# Por fim, vamos criar uma função para adivinhar os animaizinhos?

# %%
#Função para adivinhar o animal
def find_animal(filepath):
    # Converte o caminho do arquivo para uma imagem
    image = cv2.imread(filepath)
    # Redimensione a imagem e normalize o intervalo de pixels para ficar entre 0 e 1
    img = cv2.resize(image, (image_size, image_size)).astype('float32') / 255.0
    # Expandir a forma do array de imagens
    img = np.expand_dims(img, axis=0)
    # Usando o modelo para prever o animal que representa a imagem
    pred = model.predict(img)
    # Definindo uma variável para armazenar o índice que representa o caractere que representa a imagem
    classes=np.argmax(pred,axis=1)
    # Print no nome do animal previsto
    print(animal_names[classes[0]])
    # Plote a imagem do animal
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    # Desliga o eixo de plotagem
    plt.axis('off')

# %%
imagetotest = 'C:\\Users\\User\\Downloads\\imgEmilio.jpg'

# %% [markdown]
# # Testando o modelo
#
# Testando a capacidade da rede neural em reconhecer com precisão imagens inéditas de cães e gatos.

# %%
find_animal(imagetotest)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# cat
